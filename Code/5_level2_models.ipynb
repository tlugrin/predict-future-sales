# %% [markdown]
# # Second-level models
#
# Simple models trained on meta-features, or predictions of first-level models.
#
# 1. simple model averaging (best performing, validation error 0.68)
# 2. linear model (penalised using Ridge regression, second-best performing, validation error 0.87)
# 3. gradient boosting with shallow trees (no significant improvement on single best model)

# %%
import numpy as np
import pandas as pd
import pickle
import os
from sklearn import linear_model
from sklearn import metrics
from catboost import CatBoostRegressor
from catboost import Pool
import itertools

# %%
DATA_FOLDER = '../Data/'
INTERM_RES_FOLDER = "../Intermediary results"
test = pd.read_csv(os.path.join(DATA_FOLDER, 'test.csv.gz'))
with open(os.path.join(INTERM_RES_FOLDER, "sets_level2.p"), "rb") as f:
    X_level2,y_level2,months_level2 = pickle.load(f)
    
with open(os.path.join(INTERM_RES_FOLDER, "sets.p"), "rb") as f:
    Xall,yall = pickle.load(f)

# %% [markdown]
# ## 1. Model averaging

# %%
weights_regr = np.linspace(0,1,51)
weights_knn = np.linspace(0,1,51)
weights_cat = np.linspace(0,1,51)
n_comb = 22907
results = pd.DataFrame({"w_regr": np.zeros(n_comb),
                        "w_knn": np.zeros(n_comb),
                        "w_cat": np.zeros(n_comb),
                        "w_nn": np.zeros(n_comb),
                        "MSE": np.zeros(n_comb)})
i = 0
for w1 in weights_regr:
    weights_knn_valid = weights_knn[weights_knn <= 1-w1]
    for w2 in weights_knn_valid:
        weights_cat_valid = weights_cat[weights_cat <= 1-w1-w2]
        for w3 in weights_cat_valid:
            w4 = 1-w1-w2-w3
            pred = X_level2.dot(np.r_[w1,w2,w3,w4])
            results.iloc[i,:4] = [w1,w2,w3,w4]
            results.iloc[i, 4] = metrics.mean_squared_error(y_pred=pred, y_true=y_level2.clip(0,20))
            i+=1

# %%
best_weights = results.iloc[results.MSE.argmin()]
print(best_weights)
# Out:
# w_regr    0.060000
# w_knn     0.040000
# w_cat     0.620000
# w_nn      0.280000
# MSE       0.685883
# Name: 3882, dtype: float64

# %%
ytest = X_level2[months_level2 == 34].dot(np.r_[best_weights[:4]])
submission = Xall.loc[Xall.date_block_num == 34, ["shop_id","item_id"]]
submission["item_cnt_month"] = ytest
submission.loc[submission.shop_id == 11, "shop_id"] = 10
submission = test.merge(submission, how="left", on=["shop_id","item_id"])
submission.drop(columns=["shop_id","item_id"], inplace=True)
submission.to_csv("../Submissions/submission_convcomb.csv", index=False)# 0.946

# %% [markdown]
# ## 2. Linear model

# %%
regularisation = np.linspace(0.2,3,15)
regr_level2_mse = pd.DataFrame({"alpha": regularisation, "MSE":np.zeros(len(regularisation))})

Xtrain = X_level2[months_level2 < 33]
ytrain = y_level2[months_level2 < 33]
Xtest = X_level2[months_level2 == 33]
ytest = y_level2[months_level2 == 33].clip(0, 20)

for i,reg in enumerate(regularisation):
    regr_level2 = linear_model.Ridge(normalize=True, alpha = reg)
    regr_level2.fit(Xtrain, ytrain)
    pred_level2 = regr_level2.predict(Xtest).clip(0,20)
    regr_level2_mse.at[i,"MSE"] = metrics.mean_squared_error(y_pred=pred_level2, y_true=ytest)
    
del Xtrain,ytrain,Xtest,ytest

# %%
regr_level2_mse
# Out:
#     alpha       MSE
# 0     0.2  1.030557
# 1     0.4  0.979330
# 2     0.6  0.943722
# 3     0.8  0.917798
# 4     1.0  0.898951
# 5     1.2  0.885676
# 6     1.4  0.876581
# 7     1.6  0.870799
# 8     1.8  0.867689
# 9     2.0  0.866625
# 10    2.2  0.867133
# 11    2.4  0.868854
# 12    2.6  0.871510
# 13    2.8  0.874886
# 14    3.0  0.878814

# %%
best_alpha = regr_level2_mse.at[regr_level2_mse.MSE.argmin(),"alpha"]

# %%
ytest = regr_level2.predict(X_level2[months_level2 == 34]).clip(0,20)
submission = Xall.loc[Xall.date_block_num == 34, ["shop_id","item_id"]]
submission["item_cnt_month"] = ytest
submission.loc[submission.shop_id == 11, "shop_id"] = 10
submission = test.merge(submission, how="left", on=["shop_id","item_id"])
submission.drop(columns=["shop_id","item_id"], inplace=True)
submission.to_csv("../Submissions/submission_ensemble_lr.csv", index=False)# 0.965

# %% [markdown]
# ## 3. Shallow gradient boosting

# %%
depth = [4,5,6]
regularisation = np.logspace(-2,1,4)
cat_level2_mse = pd.DataFrame({"depth": [i for i,j in itertools.product(depth,regularisation)],
                               "regul": [j for i,j in itertools.product(depth,regularisation)],
                               "MSE": np.zeros(len(depth)*len(regularisation))})

Xtrain = X_level2[months_level2 < 33]
ytrain = y_level2[months_level2 < 33]
Xtest = X_level2[months_level2 == 33]
ytest = y_level2[months_level2 == 33].clip(0,20)
pool_test = Pool(Xtest, ytest)

for d in depth:
    for reg in regularisation:
        cat = CatBoostRegressor(iterations=150,
                                learning_rate=0.05,
                                use_best_model=True,
                                loss_function="RMSE",
                                eval_metric="RMSE",
                                one_hot_max_size=2,
                                l2_leaf_reg=reg,
                                depth=d)
        cat.fit(Xtrain, ytrain, verbose=30, eval_set=pool_test)
        pred_level2 = cat.predict(Xtest).clip(0,20)
        cat_level2_mse.at[(cat_level2_mse.depth == d) & (cat_level2_mse.regul == reg),"MSE"]=\
            metrics.mean_squared_error(y_pred=pred_level2, y_true=ytest)
        
del Xtrain,ytrain,Xtest,ytest
# Out:
# 0:	learn: 3.6522190	test: 1.1129986	best: 1.1129986 (0)	total: 179ms	remaining: 26.7s
# 30:	learn: 3.4251226	test: 1.0051996	best: 0.9866700 (20)	total: 4.13s	remaining: 15.8s
# 60:	learn: 3.3537548	test: 1.0694805	best: 0.9866700 (20)	total: 7.67s	remaining: 11.2s
# 90:	learn: 3.2981658	test: 1.1196561	best: 0.9866700 (20)	total: 11.4s	remaining: 7.41s
# 120:	learn: 3.2651029	test: 1.1500617	best: 0.9866700 (20)	total: 15s	remaining: 3.6s
# 149:	learn: 3.2268400	test: 1.1700053	best: 0.9866700 (20)	total: 18.5s	remaining: 0us
#
# bestTest = 0.9866699733
# bestIteration = 20
#
# Shrink model to first 21 iterations.
# 0:	learn: 3.6523139	test: 1.1130002	best: 1.1130002 (0)	total: 117ms	remaining: 17.5s
# 30:	learn: 3.4254387	test: 1.0051348	best: 0.9866478 (20)	total: 3.49s	remaining: 13.4s
# 60:	learn: 3.3542365	test: 1.0694292	best: 0.9866478 (20)	total: 7.06s	remaining: 10.3s
# 90:	learn: 3.2986750	test: 1.1196346	best: 0.9866478 (20)	total: 10.7s	remaining: 6.92s
# 120:	learn: 3.2651810	test: 1.1513195	best: 0.9866478 (20)	total: 14.3s	remaining: 3.42s
# 149:	learn: 3.2337345	test: 1.1757341	best: 0.9866478 (20)	total: 17.8s	remaining: 0us
#
# bestTest = 0.9866478058
# bestIteration = 20
#
# Shrink model to first 21 iterations.
# 0:	learn: 3.6530802	test: 1.1130143	best: 1.1130143 (0)	total: 117ms	remaining: 17.5s
# 30:	learn: 3.4273296	test: 1.0081855	best: 0.9886338 (19)	total: 3.5s	remaining: 13.4s
# 60:	learn: 3.3631366	test: 1.0665368	best: 0.9886338 (19)	total: 7.05s	remaining: 10.3s
# 90:	learn: 3.3102173	test: 1.1193750	best: 0.9886338 (19)	total: 10.8s	remaining: 7.01s
# 120:	learn: 3.2757227	test: 1.1440358	best: 0.9886338 (19)	total: 14.7s	remaining: 3.52s
# 149:	learn: 3.2459057	test: 1.1670060	best: 0.9886338 (19)	total: 18.4s	remaining: 0us
#
# bestTest = 0.9886338197
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# 0:	learn: 3.6538877	test: 1.1143343	best: 1.1143343 (0)	total: 117ms	remaining: 17.5s
# 30:	learn: 3.4458348	test: 1.0015059	best: 0.9874463 (15)	total: 3.6s	remaining: 13.8s
# 60:	learn: 3.4035866	test: 1.0482141	best: 0.9874463 (15)	total: 7.29s	remaining: 10.6s
# 90:	learn: 3.3553818	test: 1.0855456	best: 0.9874463 (15)	total: 11.1s	remaining: 7.19s
# 120:	learn: 3.3133349	test: 1.1099136	best: 0.9874463 (15)	total: 14.9s	remaining: 3.57s
# 149:	learn: 3.2791616	test: 1.1328877	best: 0.9874463 (15)	total: 18.6s	remaining: 0us
#
# bestTest = 0.9874463203
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# 0:	learn: 3.6500912	test: 1.1143447	best: 1.1143447 (0)	total: 128ms	remaining: 19.1s
# 30:	learn: 3.3907511	test: 1.0127624	best: 0.9872500 (18)	total: 3.99s	remaining: 15.3s
# 60:	learn: 3.2942070	test: 1.0843589	best: 0.9872500 (18)	total: 8.15s	remaining: 11.9s
# 90:	learn: 3.2297010	test: 1.1350189	best: 0.9872500 (18)	total: 12.3s	remaining: 8s
# 120:	learn: 3.1987367	test: 1.1669490	best: 0.9872500 (18)	total: 16.5s	remaining: 3.96s
# 149:	learn: 3.1615618	test: 1.1973854	best: 0.9872500 (18)	total: 20.7s	remaining: 0us
#
# bestTest = 0.9872500214
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# 0:	learn: 3.6501868	test: 1.1143468	best: 1.1143468 (0)	total: 128ms	remaining: 19.1s
# 30:	learn: 3.3994821	test: 1.0078070	best: 0.9854055 (20)	total: 4s	remaining: 15.3s
# 60:	learn: 3.2948886	test: 1.0797505	best: 0.9854055 (20)	total: 8.13s	remaining: 11.9s
# 90:	learn: 3.2318779	test: 1.1356863	best: 0.9854055 (20)	total: 12.3s	remaining: 7.99s
# 120:	learn: 3.1907170	test: 1.1787691	best: 0.9854055 (20)	total: 16.5s	remaining: 3.96s
# 149:	learn: 3.1555882	test: 1.2110002	best: 0.9854055 (20)	total: 20.7s	remaining: 0us
#
# bestTest = 0.9854055328
# bestIteration = 20
#
# Shrink model to first 21 iterations.
# 0:	learn: 3.6509604	test: 1.1143655	best: 1.1143655 (0)	total: 126ms	remaining: 18.7s
# 30:	learn: 3.3946167	test: 1.0101470	best: 0.9878722 (18)	total: 4.01s	remaining: 15.4s
# 60:	learn: 3.3104666	test: 1.0780526	best: 0.9878722 (18)	total: 8.17s	remaining: 11.9s
# 90:	learn: 3.2530663	test: 1.1259268	best: 0.9878722 (18)	total: 12.4s	remaining: 8.02s
# 120:	learn: 3.2068109	test: 1.1619347	best: 0.9878722 (18)	total: 16.6s	remaining: 3.97s
# 149:	learn: 3.1764598	test: 1.1946237	best: 0.9878722 (18)	total: 20.7s	remaining: 0us
#
# bestTest = 0.9878722267
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# 0:	learn: 3.6530112	test: 1.1141523	best: 1.1141523 (0)	total: 136ms	remaining: 20.3s
# 30:	learn: 3.4253156	test: 1.0102697	best: 0.9906414 (19)	total: 4s	remaining: 15.4s
# 60:	learn: 3.3578239	test: 1.0588153	best: 0.9906414 (19)	total: 8.11s	remaining: 11.8s
# 90:	learn: 3.3122214	test: 1.0861975	best: 0.9906414 (19)	total: 12.3s	remaining: 7.96s
# 120:	learn: 3.2734388	test: 1.1187095	best: 0.9906414 (19)	total: 16.5s	remaining: 3.94s
# 149:	learn: 3.2482324	test: 1.1478616	best: 0.9906414 (19)	total: 20.5s	remaining: 0us
#
# bestTest = 0.9906414177
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# 0:	learn: 3.6488981	test: 1.1134410	best: 1.1134410 (0)	total: 142ms	remaining: 21.2s
# 30:	learn: 3.3625189	test: 1.0135209	best: 0.9909252 (19)	total: 4.44s	remaining: 17.1s
# 60:	learn: 3.2639900	test: 1.0927610	best: 0.9909252 (19)	total: 8.94s	remaining: 13s
# 90:	learn: 3.1938483	test: 1.1464116	best: 0.9909252 (19)	total: 13.6s	remaining: 8.8s
# 120:	learn: 3.1188470	test: 1.1897068	best: 0.9909252 (19)	total: 18.4s	remaining: 4.41s
# 149:	learn: 3.0813103	test: 1.2281124	best: 0.9909252 (19)	total: 23s	remaining: 0us
#
# bestTest = 0.9909251562
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# 0:	learn: 3.6489945	test: 1.1134432	best: 1.1134432 (0)	total: 141ms	remaining: 21s
# 30:	learn: 3.3604144	test: 1.0149015	best: 0.9881297 (17)	total: 4.45s	remaining: 17.1s
# 60:	learn: 3.2455080	test: 1.0956253	best: 0.9881297 (17)	total: 8.99s	remaining: 13.1s
# 90:	learn: 3.1779030	test: 1.1679000	best: 0.9881297 (17)	total: 13.6s	remaining: 8.81s
# 120:	learn: 3.1038557	test: 1.2143228	best: 0.9881297 (17)	total: 18.2s	remaining: 4.37s
# 149:	learn: 3.0646783	test: 1.2501824	best: 0.9881297 (17)	total: 22.7s	remaining: 0us
#
# bestTest = 0.9881297284
# bestIteration = 17
#
# Shrink model to first 18 iterations.
# 0:	learn: 3.6497752	test: 1.1134632	best: 1.1134632 (0)	total: 143ms	remaining: 21.3s
# 30:	learn: 3.3742498	test: 1.0102647	best: 0.9875316 (18)	total: 4.45s	remaining: 17.1s
# 60:	learn: 3.2681214	test: 1.0949865	best: 0.9875316 (18)	total: 8.98s	remaining: 13.1s
# 90:	learn: 3.2080901	test: 1.1478165	best: 0.9875316 (18)	total: 13.6s	remaining: 8.81s
# 120:	learn: 3.1386431	test: 1.1782430	best: 0.9875316 (18)	total: 18.3s	remaining: 4.38s
# 149:	learn: 3.0962262	test: 1.2143200	best: 0.9875316 (18)	total: 22.8s	remaining: 0us
#
# bestTest = 0.9875315979
# bestIteration = 18
#
# Shrink model to first 19 iterations.
# 0:	learn: 3.6518679	test: 1.1133023	best: 1.1133023 (0)	total: 142ms	remaining: 21.2s
# 30:	learn: 3.4175737	test: 1.0122774	best: 0.9940311 (17)	total: 4.44s	remaining: 17s
# 60:	learn: 3.3478587	test: 1.0587991	best: 0.9940311 (17)	total: 8.96s	remaining: 13.1s
# 90:	learn: 3.3072408	test: 1.0858622	best: 0.9940311 (17)	total: 13.5s	remaining: 8.77s
# 120:	learn: 3.2697561	test: 1.1122972	best: 0.9940311 (17)	total: 18.1s	remaining: 4.34s
# 149:	learn: 3.2335970	test: 1.1469095	best: 0.9940311 (17)	total: 22.5s	remaining: 0us
#
# bestTest = 0.994031128
# bestIteration = 17
#
# Shrink model to first 18 iterations.

# %%
cat_level2_mse
# Out:
#     depth  regul       MSE
# 0       4   0.01  0.961278
# 1       4   0.10  0.961270
# 2       4   1.00  0.968395
# 3       4  10.00  0.972286
# 4       5   0.01  0.957860
# 5       5   0.10  0.948085
# 6       5   1.00  0.959101
# 7       5  10.00  0.954850
# 8       6   0.01  0.946747
# 9       6   0.10  0.955517
# 10      6   1.00  0.950738
# 11      6  10.00  0.962565

# %%
best_depth = 5
best_alpha = 0.1
best_iter = 18

# %%
ytest = cat.predict(X_level2[months_level2 == 34]).clip(0,20)
submission = Xall.loc[Xall.date_block_num == 34, ["shop_id","item_id"]]
submission["item_cnt_month"] = ytest
submission.loc[submission.shop_id == 11, "shop_id"] = 10
submission = test.merge(submission, how="left", on=["shop_id","item_id"])
submission.drop(columns=["shop_id","item_id"], inplace=True)
submission.to_csv("../Submissions/submission_ensemble_cat.csv", index=False)
